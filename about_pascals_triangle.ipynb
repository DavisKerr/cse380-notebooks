# %% [markdown]
# <a href="https://colab.research.google.com/github/DavisKerr/cse380-notebooks/blob/master/about_pascals_triangle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # About Pascal’s Triangle
# ## Class Directed Learning
# ### Due: Tuesday, 2 February 2021, 11:59 pm

# %% [markdown]
# ## A Helper Function
# Exercise 253 on page 161 shows a recursive definition of `nCk`. Here's a much more efficient way to compute binomial coefficients, which perhaps you can profitably use in your investigations:

# %%
from math import gcd

def nCk(n, k):
  if k < 0 or k > n:
    return 0
  else:
    result = 1
    d = 1
    g = 1
    m = min(k, n - k)
    while (d <= m):
      g = gcd(result, d)
      result = n * (result // g)
      result = (result // (d // g))
      n -= 1
      d += 1
    return result

# %%
def check_row_for_fib(row):
  if len(row) > 2:
    start = 0
    end  = 2
    while end < len(row):
      if row[start] + row[start + 1] == row[end]:
        return True
      else:
        end += 1
        start += 1
    return False

def check_row_for_ratio(row):
  if len(row) > 2:
    start = 0
    end  = 2
    while end < len(row):
      if (row[start] / row[start + 1]) == (1/2) and (row[start + 1] / row[end]) == 2/3:
        return True
      else:
        end += 1
        start += 1
    return False

def gen_tri(rows):
  n = 0
  while n < rows:
    row = []
    for k in range(0, n + 1):
      row.append(nCk(n,k))
    if check_row_for_fib(row):
      print(f'At row {n} there are fibanacci numbers:')
      print(f'\t{row}')
    if check_row_for_ratio(row):
      print(f'At row {n} there are 1:2:3 ratio numbers:')
      print(f'\t{row}')
      #print(f'{nCk(n,k)}', end=" ")
    n += 1
    #print(f'\n')


gen_tri(900)
# Out:
# At row 14 there are fibanacci numbers:
# 	[1, 14, 91, 364, 1001, 2002, 3003, 3432, 3003, 2002, 1001, 364, 91, 14, 1]
# At row 14 there are 1:2:3 ratio numbers:
# 	[1, 14, 91, 364, 1001, 2002, 3003, 3432, 3003, 2002, 1001, 364, 91, 14, 1]
# At row 103 there are fibanacci numbers:
# 	[1, 103, 5253, 176851, 4421275, 87541245, 1429840335, 19813501785, 237762021420, 2509710226100, 23591276125340, 199453516332420, 1529143625215220, 10704005376506540, 68811463134684900, 408281347932463740, 2245547413628550570, 11491919116804935270, 54905835780290246290, 245631370596035312350, 1031651756503348311870, 4077480751894186185010, 15197882802514693962310, 53522978565377835258570, 178409928551259450861900, 563775374221979864723604, 1691326122665939594170812, 4823411535010272175968612, 13092117023599310191914804, 33858923336894767737710700, 83518677564340427086353060, 196673014909575844429153980, 442514283546545649965596455, 952076185812264883259313585, 1960156853142898289063292675, 3864309224767428055581919845, 7299250757894030771654737485, 13217562183213515181104524635, 22956818528739263209286805945, 38261364214565438682144676575, 61218182743304701891431482520, 94066963727516980955126424360, 138860755978715543314710435960, 196988514295387166097612478920, 268620701311891590133107925800, 352191586164480084841185947160, 444067652120431411321495324680, 538550131294991286070749649080, 628308486510823167082541257260, 705244219552964779378362635700, 761663757117201961728631646556, 791532924062974587678774064068, 791532924062974587678774064068, 761663
733400039682736650628772345313243230966255594869280666878328, 6445022247639770384647852667151677892396573884220495195045143123937291208150735120, 77223084748992885154235180139144649656169857994569206064268169430448634657660626256, 907371245800666400562263366634949633459995831436188171255150990807771457227512358508, 10458647517386628511743983015423893143565215109711853131835687736152734164885537184908, 118290909851821177650069876864104722451358295033982338870417433705451614002843317125856, 1313229592422760531538911344847264291621011580462007321358024052153742494438345300295520, 14314202557408089793774133658835180778669026227035879802802462168475793189377963773221168, 153232365081762010415319824249497918827391379118925073954590291737945786109242792523170864, 1611411323117884367593363313075365210894502890089341100296659196986139557148811302017861344, 16651250338884805131798087568445440512576529864256524703065478368856775423871050120851233888, 169114261254298802119824326867024005205855381433855329015508764683701625398690352789895344175, 1688540854677537270396399817487670451978463731547263208170233665841882382826923676317570436455, 16578401118652184109346470935333491710334007546100402407489566900993027031391614276572509739740, 160092918265193479384286070077026405023673177348163587427548504252872962527020513984215131367340, 1520882723519338054150717665731750847724895184807554080561710790402293144006694882850043747989730, 14216947198115 ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-a690ca0ce02e> in <module>()
#      40
#      41
# ---> 42 gen_tri(1800)
#
# <ipython-input-38-a690ca0ce02e> in gen_tri(rows)
#      28     row = []
#      29     for k in range(0, n + 1):
# ---> 30       row.append(nCk(n,k))
#      31     if check_row_for_fib(row):
#      32       print(f'At row {n} there are fibanacci numbers:')
#
# <ipython-input-6-792fda0ea3aa> in nCk(n, k)
#      12       g = gcd(result, d)
#      13       result = n * (result // g)
# ---> 14       result = (result // (d // g))
#      15       n -= 1
#      16       d += 1
#
# KeyboardInterrupt:

# %% [markdown]
# ## Predominant and Fundamental
# The predominant pattern, the fundamental symmetry in Pascal's triangle is captured by the identity:
# $${n \choose k} = {n \choose n - k}$$
# ## Identify Identities
# Here are two different identities that point out the same pattern in Pascal's triangle. What is the name of this pattern?
# ### Identity 1
# For nonnegative integers $r$ and $n$:
# $$\sum^n_{k=0} {r+k \choose k} = {r+n+1 \choose n}$$
# ### Identity 2
# For nonnegative integers $m$ and $n$:
# $$\sum^n_{k=0} {k \choose m} = {n+1 \choose m+1}$$

# %% [markdown]
# It would be symmetry, because pascals triangle repeats itself in reverse on the right side of the rienagle as opposed to the left.

# %% [markdown]
# # Investigate A Possible Relationship
# Does any row in Pascal's Triangle have the Fibonacci numbers' relationship between three consecutive entries? In other words, where x, y, and z are three consecutive entries in a single row, does x + y = z?
#
#   The number of rows where this relationship could possibly hold is:
#   - [ ] Zero.
#   - [X ] At least one.
#   - [ ] At most one.
#   - [ ] Exactly one.
#   - [ ] It cannot be determined.

# %% [markdown]
# # Investigate Another Possible Relationship
# Does any row in Pascal's Triangle have three consecutive entries in the ratio 1:2:3? (12:24:36 is an example of three numbers in a 1:2:3 ratio.)?
#
#   The number of rows where this relationship could possibly hold is:
#   - [ ] Zero.
#   - [ X ] At least one.
#   - [ ] At most one.
#   - [ ] Exactly one.
#   - [ ] It cannot be determined.
